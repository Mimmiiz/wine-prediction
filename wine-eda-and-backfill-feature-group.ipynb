# %%
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import hopsworks
import pandas as pd

# %%
project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# Connection closed.
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/188564
# Connected. Call `.close()` to terminate connection gracefully.

# %%
feature_names = ['type', 'fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
                 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
                 'ph', 'sulphates', 'alcohol', 'quality']

# %%
wine_red_df = pd.read_csv("winequality-red.csv", sep=";")
wine_red_df.insert(0, 'type', 1)
wine_red_df.columns = feature_names
wine_red_df
# Out:
#       type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        1            7.8             0.880         0.00             2.6
# 2        1            7.8             0.760         0.04             2.3
# 3        1           11.2             0.280         0.56             1.9
# 4        1            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1594     1            6.2             0.600         0.08             2.0
# 1595     1            5.9             0.550         0.10             2.2
# 1596     1            6.3             0.510         0.13             2.3
# 1597     1            5.9             0.645         0.12             2.0
# 1598     1            6.0             0.310         0.47             3.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    ph  \
# ...

# %%
sns.boxplot(data=wine_red_df, x='quality', y='fixed_acidity')
plt.title('Boxplot of Acidity by Wine Quality')
plt.show()

sns.boxplot(data=wine_red_df, x='quality', y='volatile_acidity')
plt.title('Boxplot of Volatile Acidity by Wine Quality')
plt.show()

sns.boxplot(data=wine_red_df, x='quality', y='citric_acid')
plt.title('Boxplot of Citric Acid by Wine Quality')
plt.show()

sns.boxplot(data=wine_red_df, x='quality', y='residual_sugar')
plt.title('Boxplot of Residual Sugar by Wine Quality')
plt.show()

sns.boxplot(data=wine_red_df, x='quality', y='chlorides')
plt.title('Boxplot of Chlorides by Wine Quality')
plt.show()

sns.boxplot(data=wine_red_df, x='quality', y='free_sulfur_dioxide')
plt.title('Boxplot of Free Sulfur Dioxide by Wine Quality')
plt.show()

sns.boxplot(data=wine_red_df, x='quality', y='total_sulfur_dioxide')
plt.title('Boxplot of Total Sulfur Dioxide by Wine Quality')
plt.show()

sns.boxplot(data=wine_red_df, x='quality', y='density')
plt.title('Boxplot of Density by Wine Quality')
plt.show()

sns.boxplot(data=wine_red_df, x='quality', y='ph')
plt.title('Boxplot of pH by Wine Quality')
plt.show()

sns.boxplot(data=wine_red_df, x='quality', y='sulphates')
plt.title('Boxplot of Sulphates by Wine Quality')
plt.show()

sns.boxplot(data=wine_red_df, x='quality', y='alcohol')
plt.title('Boxplot of Alcohol by Wine Quality')
plt.show()

# %%
wine_white_df = pd.read_csv("winequality-white.csv", sep=";")
wine_white_df.insert(0, 'type', 1)
wine_white_df.columns = feature_names
wine_white_df
# Out:
#       type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.0              0.27         0.36            20.7
# 1        1            6.3              0.30         0.34             1.6
# 2        1            8.1              0.28         0.40             6.9
# 3        1            7.2              0.23         0.32             8.5
# 4        1            7.2              0.23         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 4893     1            6.2              0.21         0.29             1.6
# 4894     1            6.6              0.32         0.36             8.0
# 4895     1            6.5              0.24         0.19             1.2
# 4896     1            5.5              0.29         0.30             1.1
# 4897     1            6.0              0.21         0.38             0.8
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    ph  \
# ...

# %%
sns.boxplot(data=wine_white_df, x='quality', y='fixed_acidity')
plt.title('Boxplot of Acidity by Wine Quality')
plt.show()

sns.boxplot(data=wine_white_df, x='quality', y='volatile_acidity')
plt.title('Boxplot of Volatile Acidity by Wine Quality')
plt.show()

sns.boxplot(data=wine_white_df, x='quality', y='citric_acid')
plt.title('Boxplot of Citric Acid by Wine Quality')
plt.show()

sns.boxplot(data=wine_white_df, x='quality', y='residual_sugar')
plt.title('Boxplot of Residual Sugar by Wine Quality')
plt.show()

sns.boxplot(data=wine_white_df, x='quality', y='chlorides')
plt.title('Boxplot of Chlorides by Wine Quality')
plt.show()

sns.boxplot(data=wine_white_df, x='quality', y='free_sulfur_dioxide')
plt.title('Boxplot of Free Sulfur Dioxide by Wine Quality')
plt.show()

sns.boxplot(data=wine_white_df, x='quality', y='total_sulfur_dioxide')
plt.title('Boxplot of Total Sulfur Dioxide by Wine Quality')
plt.show()

sns.boxplot(data=wine_white_df, x='quality', y='density')
plt.title('Boxplot of Density by Wine Quality')
plt.show()

sns.boxplot(data=wine_white_df, x='quality', y='ph')
plt.title('Boxplot of pH by Wine Quality')
plt.show()

sns.boxplot(data=wine_white_df, x='quality', y='sulphates')
plt.title('Boxplot of Sulphates by Wine Quality')
plt.show()

sns.boxplot(data=wine_white_df, x='quality', y='alcohol')
plt.title('Boxplot of Alcohol by Wine Quality')
plt.show()

# %%
wine_df = pd.concat([wine_red_df, wine_white_df], ignore_index=True)
wine_df
# Out:
#       type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4              0.70         0.00             1.9
# 1        1            7.8              0.88         0.00             2.6
# 2        1            7.8              0.76         0.04             2.3
# 3        1           11.2              0.28         0.56             1.9
# 4        1            7.4              0.70         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 6492     1            6.2              0.21         0.29             1.6
# 6493     1            6.6              0.32         0.36             8.0
# 6494     1            6.5              0.24         0.19             1.2
# 6495     1            5.5              0.29         0.30             1.1
# 6496     1            6.0              0.21         0.38             0.8
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    ph  \
# ...

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   int64
#  1   fixed_acidity         6497 non-null   float64
#  2   volatile_acidity      6497 non-null   float64
#  3   citric_acid           6497 non-null   float64
#  4   residual_sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free_sulfur_dioxide   6497 non-null   float64
#  7   total_sulfur_dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   ph                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 660.0 KB

# %%
wine_df.describe()
# Out:
# ...
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
# ...
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#          type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count  6497.0    6497.000000       6497.000000  6497.000000     6497.000000
# mean      1.0       7.215307          0.339666     0.318633        5.443235
# std       0.0       1.296434          0.164636     0.145318        4.757804
# min       1.0       3.800000          0.080000     0.000000        0.600000
# 25%       1.0       6.400000          0.230000     0.250000        1.800000
# 50%       1.0       7.000000          0.290000     0.310000        3.000000
# 75%       1.0       7.700000          0.400000     0.390000        8.100000
# max       1.0      15.900000          1.580000     1.660000       65.800000
#
# ...

# %%
wine_df['quality'].value_counts()
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
correlation_matrix = wine_df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %%
new_wine_df = wine_df.drop(["fixed_acidity", "residual_sugar", "free_sulfur_dioxide", 
              "total_sulfur_dioxide", "ph"], axis=1)
new_wine_df
# Out:
#       type  volatile_acidity  citric_acid  chlorides  density  sulphates  \
# 0        1              0.70         0.00      0.076  0.99780       0.56
# 1        1              0.88         0.00      0.098  0.99680       0.68
# 2        1              0.76         0.04      0.092  0.99700       0.65
# 3        1              0.28         0.56      0.075  0.99800       0.58
# 4        1              0.70         0.00      0.076  0.99780       0.56
# ...    ...               ...          ...        ...      ...        ...
# 6492     1              0.21         0.29      0.039  0.99114       0.50
# 6493     1              0.32         0.36      0.047  0.99490       0.46
# 6494     1              0.24         0.19      0.041  0.99254       0.46
# 6495     1              0.29         0.30      0.022  0.98869       0.38
# 6496     1              0.21         0.38      0.020  0.98941       0.32
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# ...

# %%
wine_fg = fs.get_or_create_feature_group(
    name="wine",
    version=1,
    primary_key=["type", "volatile_acidity", "citric_acid", "chlorides", "density", "sulphates", "alcohol"], 
    description="Wine quality dataset")
wine_fg.insert(new_wine_df)
# Out:
# 2023-11-19 06:30:35,442 INFO: 	7 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://c.app.hopsworks.ai:443/p/188564/fs/188483/fg/235885
# Uploading Dataframe: 0.00% |          | Rows 0/6497 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: wine_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/188564/jobs/named/wine_1_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x7f17b71d6aa0>,
#  {
#    "success": true,
#    "meta": {
#      "great_expectations_version": "0.14.13",
#      "expectation_suite_name": "iris_dimensions",
#      "run_id": {
#        "run_time": "2023-11-19T05:30:35.441882+00:00",
#        "run_name": null
#      },
#      "batch_kwargs": {
#        "ge_batch_id": "c3e14db8-869c-11ee-a702-00155df21ff9"
#      },
#      "batch_markers": {},
#      "batch_parameters": {},
# ...

# %%
from great_expectations.core import ExpectationSuite, ExpectationConfiguration

def expect(suite, column, min_val, max_val):
    suite.add_expectation(
    ExpectationConfiguration(
        expectation_type="expect_column_values_to_be_between",
        kwargs={
            "column":column, 
            "min_value":min_val,
            "max_value":max_val,
        }
    )
)

# %%
suite = ExpectationSuite(expectation_suite_name="wine_characteristics")

expect(suite, "type", 0, 1)
expect(suite, "volatile_acidity", 0.08, 1.58)
expect(suite, "citric_acid", 0, 1.66)
expect(suite, "chlorides", 0.009, 0.611)
expect(suite, "density", 0.98711, 1.03898)
expect(suite, "sulphates", 0.22, 2)
expect(suite, "alcohol", 8, 14.9)
wine_fg.save_expectation_suite(expectation_suite=suite, validation_ingestion_policy="STRICT")
# Out:
# Attached expectation suite to Feature Group, edit it at https://c.app.hopsworks.ai:443/p/188564/fs/188483/fg/235885
